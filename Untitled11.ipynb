# %%
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf
import os
# Out:
# 2023-02-25 07:32:23.955731: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-25 07:32:23.955835: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
directory = '/home/mike/Downloads/cats vs rabbits/train-cat-rabbit'

data = tf.keras.utils.image_dataset_from_directory(
    directory,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    validation_split=0.2,
    subset="training",
    seed=123,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 1600 files belonging to 2 classes.
# Using 1280 files for training.

# %%
directory = '/home/mike/Downloads/cats vs rabbits/train-cat-rabbit'

data = tf.keras.utils.image_dataset_from_directory(
    directory,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    validation_split=0.2,
    subset="validation",
    seed=123,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 1600 files belonging to 2 classes.
# Using 320 files for validation.

# %%
tf.random.set_seed(0)

# %%
class_names=data.class_names 
class_names
# Out:
# ['cat', 'rabbit']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 20))
for images, labels in data.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    # plt.title(labels[i])
    plt.title(class_names[labels[i]])
    plt.axis("off")
plt.show()

# %%
data= data.map(lambda x, y:(x/255,y))

# %%
len(data)
# Out:
# 10

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from keras.callbacks import EarlyStopping

# %%
model = Sequential()

# %%
#

model.add(Conv2D(16, (3, 3), activation='relu', input_shape=(256,256,3)))
model.add(Conv2D(32,(3,3),1 , activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32,(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32,(3,3),1 , activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(256, activation ='relu'))
# model.add(Dense(1,activation='sigmoid'))
model.add(Dense(2,activation='softmax'))

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_5 (Conv2D)           (None, 254, 254, 16)      448
#
#  conv2d_6 (Conv2D)           (None, 252, 252, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 126, 126, 32)     0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 124, 124, 32)      9248
#
#  max_pooling2d_5 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)        18464
#
#  max_pooling2d_7 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_2 (Dense)             (None, 256)               1605888
#
#  dense_3 (Dense)             (None, 2)                 514
#
# ...
# Total params: 1,657,698
# Trainable params: 1,657,698
# ...

# %%
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
tf.keras.callbacks.Callback()

# %%
logdir = '/logs'

# %%
tensorboard_callback =tf.keras.callbacks.TensorBoard(log_dir = logdir)
es = EarlyStopping(monitor='val_loss', mode='min', patience=5)

# %%
hist= model.fit(data, epochs =10,validation_data =val, callbacks=[tensorboard_callback,es])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 hist= model.fit(data, epochs =10,validation_data =val, callbacks=[tensorboard_callback,es])
#
# NameError: name 'val' is not defined
